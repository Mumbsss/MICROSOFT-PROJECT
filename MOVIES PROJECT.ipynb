# %% [markdown]
# # MOVIES ANALYSIS
# BY ODHIAMBO MUMBI

# %% [markdown]
# BUSINESS UNDERSTANDING
#
# Currently most big companies have began creating original video content allover. Microsoft has seen this and wants to invest in the same and as such I hae been tasked with getting information that will help them break into that sector. They have decided to create a newmovie studio, but have no idea on anything to do with creating movies. I have therefore been charged with finding out the types of movies currently doing well in the box office, translate these findings and into actual insights that will help Microsoft make a more informed decision. I therefore chose to come up with prompts to help me analyse the data set and put out relevant information to them.They include:
#
# 1. Currently what genre/s of movies are doing well when it comes to ratings?
# 2. Which films are currently rated the highest at the box office?
# 3. What was the production budget for these films and what is their current return revenue?
# 4. Which production companies have produces some of the movies currently ranked the highest?
# 5. Which is the release dates of some of the movies doing well when it comes to ranking?

# %% [markdown]
# DATA UNDERSTANDING
#
# For me to be able to source the data  want to work with and get clear insights on my prompts, i sourced the data from a highly credible dataset:
# bom.movie_gross.csv.gz
#
# This is a csv file,where each record represents the movie,its genre, the release data,,production_budget amongsth a lot of ther columns.From this dataset I selected the following columns:
#
# 1. popularity -which gave me information on the general ratings of different movies
# 2. budget - amount that was spent on the filming projects and other costs incurred during the movie production
# 3. revenue - the amount that the movies was able to generate after its release
# 4. release data - the year and month that the movie was released
# 5. genre - the exact type of movie that is popular in theatres currently
# 6. vote count - how many people voted for the movie in terms of ranking
# 7.production companies - the company tasked with producing the movies

# %% [markdown]
# DATA PREPARATION
#
# 1. Loading the data with thevarious libraries i was to use.
#
#  I loaded the data with the pandas ibrary then proceeded to carry on with the data cleaning process.

# %% [markdown]
# i. Importing data from the various libraries

# %%
#importing the various libraries
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# Loading data from the csv file

# %%
imdb_df=pd.read_csv(r"C:\Users\User\Documents\MORINGA ASSESMENTS\tmdb_movies_data.csv\tmdb_movies_data.csv")
imdb_df.head()
# Out:
#        id    imdb_id  popularity     budget     revenue
# 0  135397  tt0369610   32.985763  150000000  1513528810  \
# 1   76341  tt1392190   28.419936  150000000   378436354
# 2  262500  tt2908446   13.112507  110000000   295238201
# 3  140607  tt2488496   11.173104  200000000  2068178225
# 4  168259  tt2820852    9.335014  190000000  1506249360
#
#                  original_title
# 0                Jurassic World  \
# 1            Mad Max: Fury Road
# 2                     Insurgent
# 3  Star Wars: The Force Awakens
# 4                     Furious 7
#
#                                                 cast
# 0  Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...  \
# 1  Tom Hardy|Charlize Theron|Hugh Keays-Byrne|Nic...
# 2  Shailene Woodley|Theo James|Kate Winslet|Ansel...
# 3  Harrison Ford|Mark Hamill|Carrie Fisher|Adam D...
# 4  Vin Diesel|Paul Walker|Jason Statham|Michelle ...
#
#                                             homepage          director
# 0                      http://www.jurassicworld.com/   Colin Trevorrow  \
# 1                        http://www.madmaxmovie.com/     George Miller
# 2     http://www.thedivergentseries.movie/#insurgent  Robert Schwentke
# 3  http://www.starwars.com/films/star-wars-episod...       J.J. Abrams
# 4                           http://www.furious7.com/         James Wan
#
#                          tagline  ...
# 0              The park is open.  ...  \
# 1             What a Lovely Day.  ...
# 2     One Choice Can Destroy You  ...
# 3  Every generation has a story.  ...
# 4            Vengeance Hits Home  ...
#
#                                             overview runtime
# 0  Twenty-two years after the events of Jurassic ...     124  \
# 1  An apocalyptic story set in the furthest reach...     120
# 2  Beatrice Prior must confront her inner demons ...     119
# 3  Thirty years after defeating the Galactic Empi...     136
# 4  Deckard Shaw seeks revenge against Dominic Tor...     137
#
#                                       genres
# 0  Action|Adventure|Science Fiction|Thriller  \
# 1  Action|Adventure|Science Fiction|Thriller
# 2         Adventure|Science Fiction|Thriller
# 3   Action|Adventure|Science Fiction|Fantasy
# 4                      Action|Crime|Thriller
#
#                                 production_companies release_date vote_count
# 0  Universal Studios|Amblin Entertainment|Legenda...     6/9/2015       5562  \
# 1  Village Roadshow Pictures|Kennedy Miller Produ...    5/13/2015       6185
# 2  Summit Entertainment|Mandeville Films|Red Wago...    3/18/2015       2480
# 3          Lucasfilm|Truenorth Productions|Bad Robot   12/15/2015       5292
# 4  Universal Pictures|Original Film|Media Rights ...     4/1/2015       2947
#
#    vote_average  release_year   budget_adj   revenue_adj
# 0           6.5          2015  137999939.3  1.392446e+09
# 1           7.1          2015  137999939.3  3.481613e+08
# 2           6.3          2015  101199955.5  2.716190e+08
# 3           7.5          2015  183999919.0  1.902723e+09
# 4           7.3          2015  174799923.1  1.385749e+09
#
# [5 rows x 21 columns]

# %% [markdown]
# 2. PERFORMING DATA CLEANING ON MY DATASET TO ENSURE I GATHER ALL HE RELEVANT INFORMATION I NEED TO CARRY ON WITH MY ANALYSIS
#
# I filteed my data and selected the main columns I would work on.
# I also proceeded to make sure ther were no dupliates by droppng them if they did exist.
# I was able to answer questons 1,2 and 5 in this section before proceeding to the visualization section.

# %%
#checking what my data frame contains
imdb_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10866 entries, 0 to 10865
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    10866 non-null  int64
#  1   imdb_id               10856 non-null  object
#  2   popularity            10866 non-null  float64
#  3   budget                10866 non-null  int64
#  4   revenue               10866 non-null  int64
#  5   original_title        10866 non-null  object
#  6   cast                  10790 non-null  object
#  7   homepage              2936 non-null   object
#  8   director              10822 non-null  object
#  9   tagline               8042 non-null   object
#  10  keywords              9373 non-null   object
#  11  overview              10862 non-null  object
#  12  runtime               10866 non-null  int64
#  13  genres                10843 non-null  object
#  14  production_companies  9836 non-null   object
#  15  release_date          10866 non-null  object
#  16  vote_count            10866 non-null  int64
#  17  vote_average          10866 non-null  float64
#  18  release_year          10866 non-null  int64
#  19  budget_adj            10866 non-null  float64
#  20  revenue_adj           10866 non-null  float64
# dtypes: float64(4), int64(6), object(11)
# memory usage: 1.7+ MB

# %% [markdown]
# Getting rid of duplicate values

# %%
#Identifying if there are any duplicate values and if so how may in total
imdb_df.duplicated().sum()
# Out:
# 1

# %%
#dropping the duplicated values and confirming that we have gotten rid of them
imdb_df.drop_duplicates(inplace=True)
imdb_df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# Dropping columns to remain with those that i need and checkingto see the films that are currently being ranked the highest.

# %%
imdb_df.drop(['id','imdb_id','homepage','tagline','keywords','overview'], axis=1)
# Out:
#        popularity     budget     revenue                original_title
# 0       32.985763  150000000  1513528810                Jurassic World  \
# 1       28.419936  150000000   378436354            Mad Max: Fury Road
# 2       13.112507  110000000   295238201                     Insurgent
# 3       11.173104  200000000  2068178225  Star Wars: The Force Awakens
# 4        9.335014  190000000  1506249360                     Furious 7
# ...           ...        ...         ...                           ...
# 10861    0.080598          0           0            The Endless Summer
# 10862    0.065543          0           0                    Grand Prix
# 10863    0.065141          0           0           Beregis Avtomobilya
# 10864    0.064317          0           0        What's Up, Tiger Lily?
# 10865    0.035919      19000           0      Manos: The Hands of Fate
#
#                                                     cast            director
# 0      Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...     Colin Trevorrow  \
# 1      Tom Hardy|Charlize Theron|Hugh Keays-Byrne|Nic...       George Miller
# 2      Shailene Woodley|Theo James|Kate Winslet|Ansel...    Robert Schwentke
# 3      Harrison Ford|Mark Hamill|Carrie Fisher|Adam D...         J.J. Abrams
# 4      Vin Diesel|Paul Walker|Jason Statham|Michelle ...           James Wan
# ...                                                  ...                 ...
# 10861  Michael Hynson|Robert August|Lord 'Tally Ho' B...         Bruce Brown
# 10862  James Garner|Eva Marie Saint|Yves Montand|Tosh...  John Frankenheimer
# 10863  Innokentiy Smoktunovskiy|Oleg Efremov|Georgi Z...      Eldar Ryazanov
# 10864  Tatsuya Mihashi|Akiko Wakabayashi|Mie Hama|Joh...         Woody Allen
# 10865  Harold P. Warren|Tom Neyman|John Reynolds|Dian...    Harold P. Warren
#
#        runtime                                     genres
# 0          124  Action|Adventure|Science Fiction|Thriller  \
# 1          120  Action|Adventure|Science Fiction|Thriller
# 2          119         Adventure|Science Fiction|Thriller
# 3          136   Action|Adventure|Science Fiction|Fantasy
# 4          137                      Action|Crime|Thriller
# ...        ...                                        ...
# 10861       95                                Documentary
# 10862      176                     Action|Adventure|Drama
# 10863       94                             Mystery|Comedy
# 10864       80                              Action|Comedy
# 10865       74                                     Horror
#
#                                     production_companies release_date
# 0      Universal Studios|Amblin Entertainment|Legenda...     6/9/2015  \
# 1      Village Roadshow Pictures|Kennedy Miller Produ...    5/13/2015
# 2      Summit Entertainment|Mandeville Films|Red Wago...    3/18/2015
# 3              Lucasfilm|Truenorth Productions|Bad Robot   12/15/2015
# 4      Universal Pictures|Original Film|Media Rights ...     4/1/2015
# ...                                                  ...          ...
# 10861                                  Bruce Brown Films    6/15/1966
# 10862  Cherokee Productions|Joel Productions|Douglas ...   12/21/1966
# 10863                                            Mosfilm     1/1/1966
# 10864                            Benedict Pictures Corp.    11/2/1966
# 10865                                          Norm-Iris   11/15/1966
#
#        vote_count  vote_average  release_year    budget_adj   revenue_adj
# 0            5562           6.5          2015  1.379999e+08  1.392446e+09
# 1            6185           7.1          2015  1.379999e+08  3.481613e+08
# 2            2480           6.3          2015  1.012000e+08  2.716190e+08
# 3            5292           7.5          2015  1.839999e+08  1.902723e+09
# 4            2947           7.3          2015  1.747999e+08  1.385749e+09
# ...           ...           ...           ...           ...           ...
# 10861          11           7.4          1966  0.000000e+00  0.000000e+00
# 10862          20           5.7          1966  0.000000e+00  0.000000e+00
# 10863          11           6.5          1966  0.000000e+00  0.000000e+00
# 10864          22           5.4          1966  0.000000e+00  0.000000e+00
# 10865          15           1.5          1966  1.276423e+05  0.000000e+00
#
# [10865 rows x 15 columns]

# %%
#finding out what genre is performing well currently as ranked in this data set
imdb_value=imdb_df['genres'].value_counts()
imdb_value
# Out:
# genres
# Comedy                                      712
# Drama                                       712
# Documentary                                 312
# Drama|Romance                               289
# Comedy|Drama                                280
#                                            ...
# Adventure|Animation|Romance                   1
# Family|Animation|Drama                        1
# Action|Adventure|Animation|Comedy|Family      1
# Action|Adventure|Animation|Fantasy            1
# Mystery|Science Fiction|Thriller|Drama        1
# Name: count, Length: 2039, dtype: int64

# %% [markdown]
# DATA VISUALIZATION

# %% [markdown]
# I opted to make use of majorly bag graphs as they are easie to comprehend and understand in order to show the various relationships between budget and revenues, and alse check if there was a definite connection between the production company and the movie ratings.

# %% [markdown]
# I used this to answer question 3 and 4 through visualizations as they would be simpler to understand.

# %%
# sorting the budgets list in descending order from largest to smallest
budgets=imdb_df.sort_values(['budget'],ascending=False)
budgets.head(30)
# Out:
#           id    imdb_id  popularity     budget     revenue
# 2244   46528  tt1032751    0.250540  425000000    11087569  \
# 3375    1865  tt1298650    4.955130  380000000  1021683000
# 7387     285  tt0449088    4.965391  300000000   961000000
# 14     99861  tt2395427    5.944927  280000000  1405035767
# 6570    1452  tt0348150    1.957331  270000000   391081192
# 4411   49529  tt0401729    1.588457  260000000   284139100
# 1929   38757  tt0398286    2.865684  260000000   591794936
# 7394     559  tt0413300    2.520912  258000000   890871626
# 5508   57201  tt1210819    1.214510  255000000    89289910
# 4367   49051  tt0903624    4.218933  250000000  1017003568
# 1923   12444  tt0926084    4.840588  250000000   954305868
# 1389     767  tt0417741    5.076472  250000000   933959197
# 5431   57158  tt1170358    4.310786  250000000   958400000
# 643   127585  tt1877832    6.052479  250000000   746000000
# 4363   49026  tt1345836    6.591277  250000000  1081041287
# 634   122917  tt2310332   10.174599  250000000   955119788
# 10    206647  tt2379713    6.200282  245000000   880674609
# 1386   19995  tt0499549    9.432768  237000000  2781505847
# 4381   41154  tt1409024    2.592896  225000000   624026776
# 2902    2454  tt0499448    1.628345  225000000   419651413
# 5432   49521  tt0770828    3.972460  225000000   662845518
# 4361   24428  tt0848228    7.637767  220000000  1519557910
# 4370    1930  tt0948470    3.702647  215000000   752215857
# 6883   36668  tt0376994    0.157586  210000000   234360014
# 648    91314  tt2109248    4.983782  210000000   245500000
# 4405   44833  tt1440129    1.630455  209000000   303025485
# 6215     254  tt0360717    1.508329  207000000   550000000
# 6555      58  tt0383574    4.205992  200000000  1065659812
# 5425   68721  tt1300854    4.946136  200000000  1215439994
# 4959     296  tt0181852    2.686888  200000000   435000000
#
#                                     original_title
# 2244                             The Warrior's Way  \
# 3375   Pirates of the Caribbean: On Stranger Tides
# 7387      Pirates of the Caribbean: At World's End
# 14                         Avengers: Age of Ultron
# 6570                              Superman Returns
# 4411                                   John Carter
# 1929                                       Tangled
# 7394                                  Spider-Man 3
# 5508                               The Lone Ranger
# 4367             The Hobbit: An Unexpected Journey
# 1923  Harry Potter and the Deathly Hallows: Part 1
# 1389        Harry Potter and the Half-Blood Prince
# 5431           The Hobbit: The Desolation of Smaug
# 643                     X-Men: Days of Future Past
# 4363                         The Dark Knight Rises
# 634      The Hobbit: The Battle of the Five Armies
# 10                                         Spectre
# 1386                                        Avatar
# 4381                                Men in Black 3
# 2902      The Chronicles of Narnia: Prince Caspian
# 5432                                  Man of Steel
# 4361                                  The Avengers
# 4370                        The Amazing Spider-Man
# 6883                         X-Men: The Last Stand
# 648                Transformers: Age of Extinction
# 4405                                    Battleship
# 6215                                     King Kong
# 6555    Pirates of the Caribbean: Dead Man's Chest
# 5425                                    Iron Man 3
# 4959            Terminator 3: Rise of the Machines
#
#                                                    cast
# 2244  Kate Bosworth|Jang Dong-gun|Geoffrey Rush|Dann...  \
# 3375  Johnny Depp|PenÃ©lope Cruz|Geoffrey Rush|Ian M...
# 7387  Johnny Depp|Orlando Bloom|Keira Knightley|Geof...
# 14    Robert Downey Jr.|Chris Hemsworth|Mark Ruffalo...
# 6570  Brandon Routh|Kevin Spacey|Kate Bosworth|James...
# 4411  Taylor Kitsch|Lynn Collins|Mark Strong|Willem ...
# 1929  Zachary Levi|Mandy Moore|Donna Murphy|Ron Perl...
# 7394  Tobey Maguire|Kirsten Dunst|James Franco|Thoma...
# 5508  Johnny Depp|Armie Hammer|William Fichtner|Hele...
# 4367  Ian McKellen|Martin Freeman|Richard Armitage|A...
# 1923  Daniel Radcliffe|Emma Watson|Rupert Grint|Ralp...
# 1389  Daniel Radcliffe|Rupert Grint|Emma Watson|Tom ...
# 5431  Martin Freeman|Ian McKellen|Richard Armitage|K...
# 643   Hugh Jackman|James McAvoy|Patrick Stewart|Mich...
# 4363  Christian Bale|Michael Caine|Gary Oldman|Anne ...
# 634   Martin Freeman|Ian McKellen|Richard Armitage|K...
# 10    Daniel Craig|Christoph Waltz|LÃ©a Seydoux|Ralp...
# 1386  Sam Worthington|Zoe Saldana|Sigourney Weaver|S...
# 4381  Will Smith|Tommy Lee Jones|Josh Brolin|Michael...
# 2902  Ben Barnes|William Moseley|Anna Popplewell|Ska...
# 5432  Henry Cavill|Amy Adams|Michael Shannon|Diane L...
# 4361  Robert Downey Jr.|Chris Evans|Mark Ruffalo|Chr...
# 4370  Andrew Garfield|Emma Stone|Rhys Ifans|Denis Le...
# 6883  Hugh Jackman|Halle Berry|Ian McKellen|Patrick ...
# 648   Mark Wahlberg|Stanley Tucci|Nicola Peltz|Jack ...
# 4405  Taylor Kitsch|Alexander SkarsgÃ¥rd|Rihanna|Bro...
# 6215  Naomi Watts|Jack Black|Adrien Brody|Thomas Kre...
# 6555  Johnny Depp|Orlando Bloom|Keira Knightley|Bill...
# 5425  Robert Downey Jr.|Gwyneth Paltrow|Guy Pearce|D...
# 4959  Arnold Schwarzenegger|Nick Stahl|Claire Danes|...
#
#                                                homepage
# 2244             http://www.iamrogue.com/thewarriorsway  \
# 3375  http://disney.go.com/pirates/index-on-stranger...
# 7387       http://disney.go.com/disneypictures/pirates/
# 14    http://marvel.com/movies/movie/193/avengers_ag...
# 6570                            http://www.superman.com
# 4411                   http://disney.go.com/johncarter/
# 1929       http://disney.go.com/disneypictures/tangled/
# 7394    http://www.sonypictures.com/movies/spider-man3/
# 5508              http://disney.go.com/the-lone-ranger/
# 4367                          http://www.thehobbit.com/
# 1923                         http://www.harrypotter.com
# 1389  http://harrypotter.warnerbros.com/harrypottera...
# 5431                          http://www.thehobbit.com/
# 643                         http://www.x-menmovies.com/
# 4363                 http://www.thedarkknightrises.com/
# 634                           http://www.thehobbit.com/
# 10          http://www.sonypictures.com/movies/spectre/
# 1386                        http://www.avatarmovie.com/
# 4381    http://www.sonypictures.com/movies/meninblack3/
# 2902                                                NaN
# 5432                         http://www.manofsteel.com/
# 4361                  http://marvel.com/avengers_movie/
# 4370                 http://www.theamazingspiderman.com
# 6883                                                NaN
# 648                    http://www.transformersmovie.com
# 4405                                                NaN
# 6215                                                NaN
# 6555       http://disney.go.com/disneypictures/pirates/
# 5425                         http://marvel.com/ironman3
# 4959                                                NaN
#
#                        director
# 2244                 Sngmoo Lee  \
# 3375               Rob Marshall
# 7387             Gore Verbinski
# 14                  Joss Whedon
# 6570               Bryan Singer
# 4411             Andrew Stanton
# 1929  Nathan Greno|Byron Howard
# 7394                  Sam Raimi
# 5508             Gore Verbinski
# 4367              Peter Jackson
# 1923                David Yates
# 1389                David Yates
# 5431              Peter Jackson
# 643                Bryan Singer
# 4363          Christopher Nolan
# 634               Peter Jackson
# 10                   Sam Mendes
# 1386              James Cameron
# 4381           Barry Sonnenfeld
# 2902             Andrew Adamson
# 5432                Zack Snyder
# 4361                Joss Whedon
# 4370                  Marc Webb
# 6883               Brett Ratner
# 648                 Michael Bay
# 4405                 Peter Berg
# 6215              Peter Jackson
# 6555             Gore Verbinski
# 5425                Shane Black
# 4959            Jonathan Mostow
#
#                                                 tagline  ...
# 2244                            Assassin. Hero. Legend.  ...  \
# 3375                        Live Forever Or Die Trying.  ...
# 7387     At the end of the world, the adventure begins.  ...
# 14                                  A New Age Has Come.  ...
# 6570                                                NaN  ...
# 4411               Lost in Our World. Found in Another.  ...
# 1929           They're taking adventure to new lengths.  ...
# 7394                                 The battle within.  ...
# 5508                            Never Take Off the Mask  ...
# 4367  From the smallest beginnings come the greatest...  ...
# 1923                   One Wayâ€¦ One Fateâ€¦ One Hero.  ...
# 1389                              Dark Secrets Revealed  ...
# 5431  Beyond darkness... beyond desolation... lies t...  ...
# 643        To save the future, they must alter the past  ...
# 4363                                    The Legend Ends  ...
# 634   Witness the defining chapter of the Middle-Ear...  ...
# 10                                A Plan No One Escapes  ...
# 1386                        Enter the World of Pandora.  ...
# 4381                          They are back... in time.  ...
# 2902                               Hope has a new face.  ...
# 5432               You will believe that a man can fly.  ...
# 4361                            Some assembly required.  ...
# 4370                           The untold story begins.  ...
# 6883                                       Take a Stand  ...
# 648                   This is not war. It's extinction.  ...
# 4405                 The Battle for Earth Begins at Sea  ...
# 6215                    The eighth wonder of the world.  ...
# 6555                                      Jack is back!  ...
# 5425                Unleash the power behind the armor.  ...
# 4959                            The Machines Will Rise.  ...
#
#                                                overview runtime
# 2244  An Asian assassin (Dong-gun Jang) is forced to...     100  \
# 3375  Captain Jack Sparrow crosses paths with a woma...     136
# 7387  Captain Barbossa, long believed to be dead, ha...     169
# 14    When Tony Stark tries to jumpstart a dormant p...     141
# 6570  Set 5 years after the end of Superman II, the ...     154
# 4411  Civil War vet John Carter is transplanted to M...     132
# 1929  When the kingdom's most wanted-and most charmi...     100
# 7394  The seemingly invincible Spider-Man goes up ag...     139
# 5508  The Texas Rangers chase down a gang of outlaws...     149
# 4367  Bilbo Baggins, a hobbit enjoying his quiet lif...     169
# 1923  Harry, Ron and Hermione walk away from their l...     146
# 1389  As Harry begins his sixth year at Hogwarts, he...     153
# 5431  The Dwarves, Bilbo and Gandalf have successful...     161
# 643   The ultimate X-Men ensemble fights a war for t...     131
# 4363  Following the death of District Attorney Harve...     165
# 634   Immediately after the events of The Desolation...     144
# 10    A cryptic message from Bondâ€™s past sends him...     148
# 1386  In the 22nd century, a paraplegic Marine is di...     162
# 4381  Agents J (Will Smith) and K (Tommy Lee Jones) ...     106
# 2902  One year after their incredible adventures in ...     150
# 5432  A young boy learns that he has extraordinary p...     143
# 4361  When an unexpected enemy emerges and threatens...     143
# 4370  Peter Parker is an outcast high schooler was a...     136
# 6883  When a cure is found to treat mutations, lines...     104
# 648   As humanity picks up the pieces, following the...     165
# 4405  When mankind beams a radio signal into space, ...     131
# 6215  In 1933 New York, an overly ambitious movie pr...     187
# 6555  The high-seas adventures of happy-go-lucky tro...     151
# 5425  When Tony Stark's world is torn apart by a for...     130
# 4959  It's been 10 years since John Connor saved Ear...     109
#
#                                          genres
# 2244  Adventure|Fantasy|Action|Western|Thriller  \
# 3375                   Adventure|Action|Fantasy
# 7387                   Adventure|Fantasy|Action
# 14             Action|Adventure|Science Fiction
# 6570   Adventure|Fantasy|Action|Science Fiction
# 4411   Action|Adventure|Fantasy|Science Fiction
# 1929                           Animation|Family
# 7394                   Fantasy|Action|Adventure
# 5508                   Action|Adventure|Western
# 4367                   Adventure|Fantasy|Action
# 1923                   Adventure|Fantasy|Family
# 1389                   Adventure|Fantasy|Family
# 5431                          Adventure|Fantasy
# 643    Action|Adventure|Fantasy|Science Fiction
# 4363                Action|Crime|Drama|Thriller
# 634                           Adventure|Fantasy
# 10                       Action|Adventure|Crime
# 1386   Action|Adventure|Fantasy|Science Fiction
# 4381              Action|Comedy|Science Fiction
# 2902                   Adventure|Family|Fantasy
# 5432   Action|Adventure|Fantasy|Science Fiction
# 4361           Science Fiction|Action|Adventure
# 4370                   Action|Adventure|Fantasy
# 6883  Adventure|Action|Science Fiction|Thriller
# 648            Science Fiction|Action|Adventure
# 4405  Thriller|Action|Adventure|Science Fiction
# 6215                     Adventure|Drama|Action
# 6555                   Adventure|Fantasy|Action
# 5425           Action|Adventure|Science Fiction
# 4959            Action|Thriller|Science Fiction
#
#                                    production_companies release_date
# 2244                           Boram Entertainment Inc.    12/2/2010  \
# 3375  Walt Disney Pictures|Jerry Bruckheimer Films|M...    5/11/2011
# 7387  Walt Disney Pictures|Jerry Bruckheimer Films|S...    5/19/2007
# 14    Marvel Studios|Prime Focus|Revolution Sun Studios    4/22/2015
# 6570  DC Comics|Legendary Pictures|Warner Bros.|Bad ...    6/28/2006
# 4411                               Walt Disney Pictures     3/7/2012
# 1929  Walt Disney Pictures|Walt Disney Animation Stu...   11/24/2010
# 7394  Columbia Pictures|Laura Ziskin Productions|Mar...     5/1/2007
# 5508  Walt Disney Pictures|Jerry Bruckheimer Films|I...     7/3/2013
# 4367  WingNut Films|New Line Cinema|Metro-Goldwyn-Ma...   11/26/2012
# 1923                          Warner Bros.|Heyday Films   10/17/2010
# 1389                          Warner Bros.|Heyday Films     7/7/2009
# 5431  WingNut Films|New Line Cinema|Metro-Goldwyn-Ma...   12/11/2013
# 643   Twentieth Century Fox Film Corporation|Donners...    5/15/2014
# 4363  Legendary Pictures|Warner Bros.|DC Entertainme...    7/16/2012
# 634   WingNut Films|New Line Cinema|3Foot7|Metro-Gol...   12/10/2014
# 10                         Columbia Pictures|Danjaq|B24   10/26/2015
# 1386  Ingenious Film Partners|Twentieth Century Fox ...   12/10/2009
# 4381  Amblin Entertainment|Media Magik Entertainment...    5/23/2012
# 2902  Walt Disney|Walden Media|Stillking Films|Ozumi...    5/15/2008
# 5432  Legendary Pictures|Warner Bros.|DC Entertainme...    6/12/2013
# 4361                                     Marvel Studios    4/25/2012
# 4370  Columbia Pictures|Laura Ziskin Productions|Mar...    6/27/2012
# 6883                                   20th Century Fox    5/24/2006
# 648   Paramount Pictures|Amblin Entertainment|Di Bon...    6/25/2014
# 4405  Universal Pictures|Hasbro|Bluegrass Films|Film 44    4/11/2012
# 6215  WingNut Films|Universal Pictures|Big Primate P...   12/14/2005
# 6555  Walt Disney Pictures|Jerry Bruckheimer Films|S...    6/20/2006
# 5425                                     Marvel Studios    4/18/2013
# 4959  Columbia Pictures|Intermedia Films|Warner Bros...     7/2/2003
#
#      vote_count  vote_average  release_year   budget_adj   revenue_adj
# 2244         74           6.4          2010  425000000.0  1.108757e+07
# 3375       3180           6.3          2011  368371256.2  9.904175e+08
# 7387       2626           6.8          2007  315500574.8  1.010654e+09
# 14         4304           7.4          2015  257599886.7  1.292632e+09
# 6570        834           5.3          2006  292050672.7  4.230205e+08
# 4411       1479           6.0          2012  246933513.2  2.698595e+08
# 1929       2019           7.3          2010  260000000.0  5.917949e+08
# 7394       2083           5.8          2007  271330494.3  9.369017e+08
# 5508       1607           6.0          2013  238688504.9  8.357833e+07
# 4367       6417           6.9          2012  237436070.3  9.658933e+08
# 1923       3467           7.4          2010  250000000.0  9.543059e+08
# 1389       3220           7.3          2009  254100108.5  9.492765e+08
# 5431       2952           7.6          2013  234008338.2  8.970944e+08
# 643        4006           7.6          2014  230272762.7  6.871339e+08
# 4363       6723           7.5          2012  237436070.3  1.026713e+09
# 634        3110           7.1          2014  230272762.7  8.797523e+08
# 10         3254           6.2          2015  225399900.8  8.102203e+08
# 1386       8458           7.1          2009  240886902.9  2.827124e+09
# 4381       3142           6.1          2012  213692463.3  5.926659e+08
# 2902        891           6.1          2008  227876992.6  4.250173e+08
# 5432       4729           6.5          2013  210607504.4  6.204455e+08
# 4361       8903           7.3          2012  208943741.9  1.443191e+09
# 4370       4837           6.4          2012  204195020.5  7.144127e+08
# 6883       2381           6.2          2006  227150523.2  2.535000e+08
# 648        2161           5.9          2014  193429120.7  2.261279e+08
# 4405       1523           5.5          2012  198496554.8  2.877967e+08
# 6215       1289           6.4          2005  231128601.0  6.141098e+08
# 6555       3181           6.8          2006  216333831.7  1.152691e+09
# 5425       6882           6.9          2013  187206670.5  1.137692e+09
# 4959       1314           5.8          2003  237070529.0  5.156284e+08
#
# [30 rows x 21 columns]

# %%
#extracting the first few budget values 
budget_heads= imdb_df['budget'].head(10)
budget_heads
# Out:
# 0    150000000
# 1    150000000
# 2    110000000
# 3    200000000
# 4    190000000
# 5    135000000
# 6    155000000
# 7    108000000
# 8     74000000
# 9    175000000
# Name: budget, dtype: int64

# %%
top_15_movies=imdb_df.head(15)
top_15_movies
# Out:
#         id    imdb_id  popularity     budget     revenue
# 0   135397  tt0369610   32.985763  150000000  1513528810  \
# 1    76341  tt1392190   28.419936  150000000   378436354
# 2   262500  tt2908446   13.112507  110000000   295238201
# 3   140607  tt2488496   11.173104  200000000  2068178225
# 4   168259  tt2820852    9.335014  190000000  1506249360
# 5   281957  tt1663202    9.110700  135000000   532950503
# 6    87101  tt1340138    8.654359  155000000   440603537
# 7   286217  tt3659388    7.667400  108000000   595380321
# 8   211672  tt2293640    7.404165   74000000  1156730962
# 9   150540  tt2096673    6.326804  175000000   853708609
# 10  206647  tt2379713    6.200282  245000000   880674609
# 11   76757  tt1617661    6.189369  176000003   183987723
# 12  264660  tt0470752    6.118847   15000000    36869414
# 13  257344  tt2120120    5.984995   88000000   243637091
# 14   99861  tt2395427    5.944927  280000000  1405035767
#
#                   original_title
# 0                 Jurassic World  \
# 1             Mad Max: Fury Road
# 2                      Insurgent
# 3   Star Wars: The Force Awakens
# 4                      Furious 7
# 5                   The Revenant
# 6             Terminator Genisys
# 7                    The Martian
# 8                        Minions
# 9                     Inside Out
# 10                       Spectre
# 11             Jupiter Ascending
# 12                    Ex Machina
# 13                        Pixels
# 14       Avengers: Age of Ultron
#
#                                                  cast
# 0   Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...  \
# 1   Tom Hardy|Charlize Theron|Hugh Keays-Byrne|Nic...
# 2   Shailene Woodley|Theo James|Kate Winslet|Ansel...
# 3   Harrison Ford|Mark Hamill|Carrie Fisher|Adam D...
# 4   Vin Diesel|Paul Walker|Jason Statham|Michelle ...
# 5   Leonardo DiCaprio|Tom Hardy|Will Poulter|Domhn...
# 6   Arnold Schwarzenegger|Jason Clarke|Emilia Clar...
# 7   Matt Damon|Jessica Chastain|Kristen Wiig|Jeff ...
# 8   Sandra Bullock|Jon Hamm|Michael Keaton|Allison...
# 9   Amy Poehler|Phyllis Smith|Richard Kind|Bill Ha...
# 10  Daniel Craig|Christoph Waltz|LÃ©a Seydoux|Ralp...
# 11  Mila Kunis|Channing Tatum|Sean Bean|Eddie Redm...
# 12  Domhnall Gleeson|Alicia Vikander|Oscar Isaac|S...
# 13  Adam Sandler|Michelle Monaghan|Peter Dinklage|...
# 14  Robert Downey Jr.|Chris Hemsworth|Mark Ruffalo...
#
#                                              homepage
# 0                       http://www.jurassicworld.com/  \
# 1                         http://www.madmaxmovie.com/
# 2      http://www.thedivergentseries.movie/#insurgent
# 3   http://www.starwars.com/films/star-wars-episod...
# 4                            http://www.furious7.com/
# 5        http://www.foxmovies.com/movies/the-revenant
# 6                     http://www.terminatormovie.com/
# 7         http://www.foxmovies.com/movies/the-martian
# 8                        http://www.minionsmovie.com/
# 9                 http://movies.disney.com/inside-out
# 10        http://www.sonypictures.com/movies/spectre/
# 11                    http://www.jupiterascending.com
# 12                        http://exmachina-movie.com/
# 13                       http://www.pixels-movie.com/
# 14  http://marvel.com/movies/movie/193/avengers_ag...
#
#                           director
# 0                  Colin Trevorrow  \
# 1                    George Miller
# 2                 Robert Schwentke
# 3                      J.J. Abrams
# 4                        James Wan
# 5   Alejandro GonzÃ¡lez IÃ±Ã¡rritu
# 6                      Alan Taylor
# 7                     Ridley Scott
# 8         Kyle Balda|Pierre Coffin
# 9                      Pete Docter
# 10                      Sam Mendes
# 11  Lana Wachowski|Lilly Wachowski
# 12                    Alex Garland
# 13                  Chris Columbus
# 14                     Joss Whedon
#
#                                               tagline  ...
# 0                                   The park is open.  ...  \
# 1                                  What a Lovely Day.  ...
# 2                          One Choice Can Destroy You  ...
# 3                       Every generation has a story.  ...
# 4                                 Vengeance Hits Home  ...
# 5     (n. One who has returned, as if from the dead.)  ...
# 6                                    Reset the future  ...
# 7                                      Bring Him Home  ...
# 8        Before Gru, they had a history of bad bosses  ...
# 9            Meet the little voices inside your head.  ...
# 10                              A Plan No One Escapes  ...
# 11                              Expand your universe.  ...
# 12  There is nothing more human than the will to s...  ...
# 13                                           Game On.  ...
# 14                                A New Age Has Come.  ...
#
#                                              overview runtime
# 0   Twenty-two years after the events of Jurassic ...     124  \
# 1   An apocalyptic story set in the furthest reach...     120
# 2   Beatrice Prior must confront her inner demons ...     119
# 3   Thirty years after defeating the Galactic Empi...     136
# 4   Deckard Shaw seeks revenge against Dominic Tor...     137
# 5   In the 1820s, a frontiersman, Hugh Glass, sets...     156
# 6   The year is 2029. John Connor, leader of the r...     125
# 7   During a manned mission to Mars, Astronaut Mar...     141
# 8   Minions Stuart, Kevin and Bob are recruited by...      91
# 9   Growing up can be a bumpy road, and it's no ex...      94
# 10  A cryptic message from Bondâ€™s past sends him...     148
# 11  In a universe where human genetic material is ...     124
# 12  Caleb, a 26 year old coder at the world's larg...     108
# 13  Video game experts are recruited by the milita...     105
# 14  When Tony Stark tries to jumpstart a dormant p...     141
#
#                                        genres
# 0   Action|Adventure|Science Fiction|Thriller  \
# 1   Action|Adventure|Science Fiction|Thriller
# 2          Adventure|Science Fiction|Thriller
# 3    Action|Adventure|Science Fiction|Fantasy
# 4                       Action|Crime|Thriller
# 5            Western|Drama|Adventure|Thriller
# 6   Science Fiction|Action|Thriller|Adventure
# 7             Drama|Adventure|Science Fiction
# 8           Family|Animation|Adventure|Comedy
# 9                     Comedy|Animation|Family
# 10                     Action|Adventure|Crime
# 11   Science Fiction|Fantasy|Action|Adventure
# 12                      Drama|Science Fiction
# 13              Action|Comedy|Science Fiction
# 14           Action|Adventure|Science Fiction
#
#                                  production_companies release_date vote_count
# 0   Universal Studios|Amblin Entertainment|Legenda...     6/9/2015       5562  \
# 1   Village Roadshow Pictures|Kennedy Miller Produ...    5/13/2015       6185
# 2   Summit Entertainment|Mandeville Films|Red Wago...    3/18/2015       2480
# 3           Lucasfilm|Truenorth Productions|Bad Robot   12/15/2015       5292
# 4   Universal Pictures|Original Film|Media Rights ...     4/1/2015       2947
# 5   Regency Enterprises|Appian Way|CatchPlay|Anony...   12/25/2015       3929
# 6             Paramount Pictures|Skydance Productions    6/23/2015       2598
# 7   Twentieth Century Fox Film Corporation|Scott F...    9/30/2015       4572
# 8       Universal Pictures|Illumination Entertainment    6/17/2015       2893
# 9   Walt Disney Pictures|Pixar Animation Studios|W...     6/9/2015       3935
# 10                       Columbia Pictures|Danjaq|B24   10/26/2015       3254
# 11  Village Roadshow Pictures|Dune Entertainment|A...     2/4/2015       1937
# 12  DNA Films|Universal Pictures International (UP...    1/21/2015       2854
# 13        Columbia Pictures|Happy Madison Productions    7/16/2015       1575
# 14  Marvel Studios|Prime Focus|Revolution Sun Studios    4/22/2015       4304
#
#     vote_average  release_year    budget_adj   revenue_adj
# 0            6.5          2015  1.379999e+08  1.392446e+09
# 1            7.1          2015  1.379999e+08  3.481613e+08
# 2            6.3          2015  1.012000e+08  2.716190e+08
# 3            7.5          2015  1.839999e+08  1.902723e+09
# 4            7.3          2015  1.747999e+08  1.385749e+09
# 5            7.2          2015  1.241999e+08  4.903142e+08
# 6            5.8          2015  1.425999e+08  4.053551e+08
# 7            7.6          2015  9.935996e+07  5.477497e+08
# 8            6.5          2015  6.807997e+07  1.064192e+09
# 9            8.0          2015  1.609999e+08  7.854116e+08
# 10           6.2          2015  2.253999e+08  8.102203e+08
# 11           5.2          2015  1.619199e+08  1.692686e+08
# 12           7.6          2015  1.379999e+07  3.391985e+07
# 13           5.8          2015  8.095996e+07  2.241460e+08
# 14           7.4          2015  2.575999e+08  1.292632e+09
#
# [15 rows x 21 columns]

# %%
#plotting a bar graph to show clearly the initial budgets across the different genres
fig,ax=plt.subplots(figsize=(10,6))
x=top_15_movies['genres']
y=top_15_movies['budget']
ax.bar(x,y,color='red')
ax.set_ylim()
ax.set_ylabel('budget for production')
ax.set_xlabel('genres')
plt.xticks(rotation=90)
ax.set_title('Budget from different genres', fontsize=15)
# Out:
# Text(0.5, 1.0, 'Budget from different genres')

# %% [markdown]
# From this bar graph, i was able to conclude that Drama/Science fiction was least budgetted for when it came to the production stage as compared to Action/Adventure/Science fiction.

# %%
#renues aross the different genres
fig,ax=plt.subplots(figsize=(10,6))
x=top_15_movies['genres']
y=top_15_movies['revenue']
ax.bar(x,y,color='red')
ax.set_ylim()
ax.set_ylabel('revenue after release')
ax.set_xlabel('genres')
plt.xticks(rotation=90)
ax.set_title('revenue from different genres', fontsize=15)
# Out:
# Text(0.5, 1.0, 'revenue from different genres')

# %% [markdown]
# Across the different genres of movies, i was able to clearly conclude that Action/Adventure/Science Fiction/Fantasy yielded the most amount of revenue with Action/ Adventure/ Science ficton and Thriller coming in at a close second. So the production companies that focused onthese two genres generated a lot of revenue after the production stage. Drama/Science fiction yielded the least amount of revenue.

# %%
#producion company and the corresponding votecount its movie got
fig,ax=plt.subplots(figsize=(10,6))
x=top_15_movies['production_companies']
y=top_15_movies['vote_count']
ax.bar(x,y,color='red')
ax.set_ylim()
ax.set_ylabel('production company name')
ax.set_xlabel('vote_count')
plt.xticks(rotation=90)
ax.set_title('Production company and the corresponding vote count', fontsize=15)
# Out:
# Text(0.5, 1.0, 'Production company and the corresponding vote count')

# %% [markdown]
# Here, we are able to see that the production company whose movie got the best vote count was Village roadshow picture/Kennedy Miller productions wit close to 6000 vote count. Universal studios/Amblin statements came in at a close second with its movie getting aslightly lower vote count.

# %% [markdown]
# # CONCLUSION
#
# I was able to draw a few conclusions from my analysis. They include:
#
# a. The genre with the highest ranings in terms of vote counts was comedy.
#
# b. For most companies, their revenues or incomes directly matched the amount they had invested in their production plan and thus i was able to conclude that the revenues and budgets had a close relationship. This would only mean that the amount invested in making the movie had a direct inflence on that which the movie generated after it was released.
#
# c. Action/Adventure movies are the most expensive to produce.
#
# d. Drama/Science fiction are the least expensive to produce and cosequenntly tend to yield a less amount of revenue.

# %% [markdown]
# # RECOMMENDATIONS
#
# Based on the conclusions i was able to draw from my analysis, I have thre main recommendations to make to the Microsoft production team:
#
# 1. They should avoid investing in the Dama/Science fiction genre as it has very minimal demand meaning that they would spend a lot of time in production and yield very minimal revenues at the end of it all.
#
# 2. They should work with the top five production companies based on my bar graph if they want to see better results,
#
# 3. Microsoft should focus more on producing comedy films if they want to break into the film industry and ensure they saty there.
